# %%
# %sql
CREATE OR REPLACE FUNCTION hr_catalog.hr_core.region_filter(region STRING)
RETURNS BOOLEAN
RETURN
CASE
    WHEN current_user() = 'neethu.mv@tigeranalytics.com' THEN TRUE
    WHEN current_user() = 'mvneethu90@gmail.com'
         THEN region = 'UK'
    ELSE FALSE
END;

# %%
# %sql
ALTER TABLE hr_catalog.hr_core.leave_balances
SET ROW FILTER hr_catalog.hr_core.region_filter
ON (region);

# %%
# %sql
SELECT
    region,
    hr_catalog.hr_core.region_filter(region) AS allowed
FROM hr_catalog.hr_core.leave_balances
LIMIT 20;
